# %%
dbutils.notebook.help()

# %%
dbutils.notebook.run("/Workspace/Users/bhargavtj7@gmail.com/notebook_02", timeout_seconds=120)

# %%
rev = dbutils.notebook.run("/Workspace/Users/bhargavtj7@gmail.com/notebook_02",100)
rev
