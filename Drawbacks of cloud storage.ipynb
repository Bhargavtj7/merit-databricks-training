# %% [markdown]
# prerequisites

# %%
df=spark.read.csv(path="/Volumes/merit_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_001.csv",header=True,inferSchema=True)
df.limit(4).display()

# %% [markdown]
# create a view

# %%
spark.read.csv(
    path = "/Volumes/merit_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_006_new_column_education.csv",
    header = True,
    inferSchema = True
).write.format("parquet").save(
    path = "/Volumes/merit_catalog/quickstart_schema/sandbox/dataset/output/output_parquet",
    mode = ("append").save(""/Volumes/merit_catalog/quickstart_schema/sandbox/dataset/output/output_parquet"")
