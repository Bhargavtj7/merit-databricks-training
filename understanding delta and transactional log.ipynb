# %% [markdown]
# Transaction 1

# %%
df = spark.read.csv("/Volumes/merit_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_001.csv",header = True,inferSchema = True)
df.write.format("delta").save(path = "/Volumes/merit_catalog/quickstart_schema/sandbox/output/output_delta",
  mode = "overwrite",)

df_delta = spark.read.load("/Volumes/merit_catalog/quickstart_schema/sandbox/output/output_delta")
df_delta.limit(6).display()

# %% [markdown]
# Transformation

# %%
df = spark.read.csv("/Volumes/merit_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_001.csv",header = True,inferSchema = True)

from pyspark.sql.functions import col
df.filter(col("country") == "India").write.format("delta").save(
  path = "/Volumes/merit_catalog/quickstart_schema/sandbox/output/output_delta",
  mode = "overwrite",
)

# %% [markdown]
# Read transaction logs

# %%
spark.read.text(
  "/Volumes/merit_catalog/quickstart_schema/sandbox/output/output_delta/_delta_log/00000000000000000000.json"
).display()

# %% [markdown]
# approach 2

# %%
from delta.tables import DeltaTable
delta_table = DeltaTable.forPath(spark,"/Volumes/merit_catalog/quickstart_schema/sandbox/output/output_delta/")
delta_table.history().display()
