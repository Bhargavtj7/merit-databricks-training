# %%
type(spark)

# %%
df_read = spark.read
type(df_read)

# %% [markdown]
# Creating DataFrames from different sources

# %%
## create dataframe from delimited file format
## head sets the first row as a colum name
## inferschema pases the entire colum and decides the column datatype
df_csv = df_read.csv("/Volumes/merit_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_001.csv",header=True,inferSchema=True)

df_csv.display()

# %%
df_sep_pipe = df_read.csv("/Volumes/merit_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_001.dat",header=True,inferSchema=True,sep = "|")

df_sep_pipe.display()

# %% [markdown]
# ##craeting a dataframe  of a json file
# df_json = spark.read.json()

# %%
df_json = spark.read.json("/Volumes/merit_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_001.json")
df_json.display()

# %%
## json file where each recor has multiple lines
df_json_multi = spark.read.json("/Volumes/merit_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_002.json",multiLine = True)
df_json_multi.display()

# %%
## json more than 2 recors multiple lines


## json file where each recor has multiple lines
df_json_multilines = spark.read.json("/Volumes/merit_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_004.json",multiLine = True)
df_json_multilines.display()

# %% [markdown]
# Dataframe from parquet

# %%
## json file where each recor has multiple lines
df_parquet = spark.read.parquet("/Volumes/merit_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users.parquet")
df_parquet.display()

# %% [markdown]
# Custom schema

# %%
from pyspark.sql.types import *
USER_SCHEMA = StructType([
    StructField("id", IntegerType()),
    StructField("age", IntegerType()),
    StructField("gender", StringType()),
    StructField("designation", StringType()),
    StructField("salary", IntegerType())
])
df_csv = spark.read.csv("/Volumes/merit_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_001.csv",header=True,schema=USER_SCHEMA)
df_csv.display()

# %% [markdown]
# bad records and null values are different
# dealing with bad records
# 1)permissive
# 2)dropmalformed
# 3)failfast

# %%
spark.read.json(path = "/Volumes/merit_catalog/quickstart_schema/sandbox/dataset/access_logs.json",mode = "PERMISSIVE").display()

# %% [markdown]
# data frame writer API

# %%
t_df_csv = spark.read.csv("/Volumes/merit_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_001.dat",header=True,inferSchema=True)

t_df_csv.write.save(format="parquet",path="/Volumes/merit_catalog/quickstart_schema/sandbox/output/output_parquet.parquet")
spark.read.parquet("/Volumes/merit_catalog/quickstart_schema/sandbox/output/output_parquet.parquet").display()

# %% [markdown]
# Modes
# 1)ERRORIFEXISTS
# 2)OVERWRITE
# 3)APPEND

# %%
t_df_csv.write.save(path="/Volumes/merit_catalog/quickstart_schema/sandbox/output/output_json.json",mode="IGNORE")

spark.read.parquet("/Volumes/merit_catalog/quickstart_schema/sandbox/output/output_parquet.parquet").count()
