# %%
dbutils.help()

# %%
dbutils.widgets.combobox(name="top_n",defaultValue="5",choices = ["5","10","15"],label="Top N")

dbutils.widgets.dropdown(name="network",defaultValue="5G",choices = ["2G","3G","4G","5G"],label="Nework")
label = "Technology Type"



dbutils.widgets.text(name="Customer_name",defaultValue="Anonymous",label="Customer Name")

# %%
print(dbutils.widgets.get("top_n"))
print(dbutils.widgets.get("network"))
print(dbutils.widgets.get("Customer_name"))
