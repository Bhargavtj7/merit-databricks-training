# %% [markdown]
# ## Prerequisites
# ## Load the data

# %%
df = spark.read.csv(
    path="/Volumes/merit_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_001.csv",
    header=True,
    inferSchema=True,
)
df.limit(4).display()

# %%
df.write.mode("overwrite").saveAsTable("merit_catalog.quickstart_schema.users_new")

# %% [markdown]
# ## Read the delta table

# %%
spark.read.table("merit_catalog.quickstart_schema.users_new").display()

# %% [markdown]
# ## Case 1: in the below example, the new data has one extra column compared to the existing data in the file

# %% [markdown]
# ### Schema Enforcement

# %%
spark.read.csv(
    path="/Volumes/merit_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_006_new_column_education.csv",
    header=True,
    inferSchema=True,
).write.mode("append").saveAsTable("merit_catalog.quickstart_schema.users_new")

# %% [markdown]
# # Schema Evolution

# %%
spark.read.csv(
    path="/Volumes/merit_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_006_new_column_education.csv",
    header=True,
    inferSchema=True,
).write.option("mergeSchema",True).mode("append").saveAsTable("merit_catalog.quickstart_schema.users_new")

# %%
spark.read.table("merit_catalog.quickstart_schema.users_new").display()

# %%
from pyspark.sql.functions import col

spark.read.table("merit_catalog.quickstart_schema.users_new").filter(
    col("id").between(2501, 2505)
).display()

# %% [markdown]
# ## Case 2: in the below example , the new data has less columns compared to the existing data in the file

# %% [markdown]
# ### Schema Enforcement

# %%
spark.read.csv(path="/Volumes/merit_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_012_less_columns.csv", header=True, inferSchema=True).write.mode("append").saveAsTable("merit_catalog.quickstart_schema.users_new")

# %%
spark.read.table("merit_catalog.quickstart_schema.users_new").display()

# %% [markdown]
# ## Case 3: the existing data and the new data has different data types and neither of the schema enforcement or schema evolution work for it

# %% [markdown]
# ### Schema Enforcement

# %%
spark.read.csv(path="/Volumes/merit_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_013_datatype_mismatch_dob.csv", header=True, inferSchema=True).write.mode("append").saveAsTable("merit_catalog.quickstart_schema.users_new")

# %%
spark.read.csv(
    path="/Volumes/merit_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_013_datatype_mismatch_dob.csv",
    header=True,
    inferSchema=True,
).write.option("mergeSchema",True).mode("append").saveAsTable("merit_catalog.quickstart_schema.users_new")

# %% [markdown]
# ## Case 4: the table names in both the existing and new data are different

# %% [markdown]
# ### Schema Enforcement

# %%
spark.read.csv(path="/Volumes/merit_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_013_less_columns_with_different_column_names.csv", header=True, inferSchema=True).write.mode("append").saveAsTable("merit_catalog.quickstart_schema.users_new")

# %% [markdown]
# ## Case 5: when the existing columns have 2 different columns each but with same records , schema enforcement wont allow but schema evolution(with merge) will do it

# %% [markdown]
# ## Case 6: the existing data and the new data has different column names but same information like user_id/ id

# %%
spark.read.csv(
    path="/Volumes/merit_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_014_less_columns_with_different_column_names.csv",header=True,inferSchema=True).select(col("u_id").alias("id"),col("f_name").alias("name")).write.mode("append").saveAsTable("merit_catalog.quickstart_schema.users_new")
